# %%
import numpy as np
import pandas as pd
import warnings as warn
import openpyxl
warn.filterwarnings('ignore')

# %%
df=pd.read_excel(r"C:\Users\ykmi1\Downloads\Campaign data.xlsx")

# %%
df
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value
# 0               Colorado Springs-Pueblo  Impressions      1.00
# ...

# %%
df.shape
# Out:
# (123699, 7)

# %%
df1=pd.read_excel(r"C:\Users\ykmi1\Downloads\Campaign data.xlsx",sheet_name=1)

# %%
df1
# Out:
#                  Campaign   Message type        Model
# 0       Sentra campaign 2  Future Market       Sentra
# 1       Sentra campaign 4  Future Market       Sentra
# 2       Sentra campaign 3  Future Market       Sentra
# 3       Sentra campaign 1  Future Market       Sentra
# 4       Altima campaign 1  Future Market       Altima
# 5       Altima campaign 5  Future Market       Altima
# 6       Altima campaign 4  Future Market       Altima
# 7       Altima campaign 6  Future Market       Altima
# 8        Kicks campaign 6  Future Market        Kicks
# 9        Kicks campaign 5  Future Market        Kicks
# 10       Rogue campaign 1  Future Market        Rogue
# 11       Rogue campaign 3  Future Market        Rogue
# 12       Rogue pre launch  Future Market        Rogue
# 13       Rogue campaign 5  Future Market        Rogue
# 14       Rogue campaign 4  Future Market        Rogue
# 15  Pathfinder campaign 3    Near Market   Pathfinder
# ...

# %%
s=pd.merge(df,df1,how='inner')#on='dataframe',,,(how=inner,outer,,left,right)(inner=common ,outer=all data ,right=all to present in right dataframe to print ,left=all to present in left dataframe to print ,)

# %%
s=pd.concat([df,df1],ignore_index=True)

# %%
s
# Out:
#              Date Data source            Campaign Media Type  \
# 0      2019-12-30   Pinterest    Kicks campaign 2    Display
# 1      2019-12-30   Pinterest    Kicks campaign 2    Display
# 2      2019-12-30   Pinterest    Kicks campaign 2    Display
# 3      2019-12-30   Pinterest    Kicks campaign 2    Display
# 4      2019-12-30   Pinterest    Kicks campaign 2    Display
# ...           ...         ...                 ...        ...
# 123752        NaT         NaN   Sentra campaign 8        NaN
# 123753        NaT         NaN  Sentra campaign 10        NaN
# 123754        NaT         NaN  Sentra campaign 24        NaN
# 123755        NaT         NaN  Sentra campaign 16        NaN
# 123756        NaT         NaN  Sentra campaign 17        NaN
#
#                             City       Metric  Value Message type   Model
# 0        Colorado Springs-Pueblo  Impressions    1.0          NaN     NaN
# 1        Colorado Springs-Pueblo   Media Cost    0.0          NaN     NaN
# ...

# %%
s.sample(10)
# Out:
#             Date Data source           Campaign    Media Type  \
# 49859 2020-12-26    Snapchat   Rogue campaign 4  Online Video
# 72811 2021-03-10    Snapchat   Kicks campaign 5  Online Video
# 22368 2020-10-10    Snapchat  Altima campaign 1  Online Video
# 13770 2020-07-27    Snapchat  Sentra campaign 1  Online Video
# 65139 2021-02-22   Pinterest   Kicks campaign 4  Online Video
# 42477 2020-11-25    Snapchat   Rogue campaign 5  Online Video
# 90646 2021-07-26   Pinterest  Altima campaign 3       Display
# 50792 2020-12-28   Pinterest   Rogue campaign 2  Online Video
# 20979 2020-10-05   Pinterest  Altima campaign 2  Online Video
# 48727 2020-12-22    Snapchat   Rogue campaign 5  Online Video
#
#                                       City       Metric     Value  \
# 49859  Orlando - Daytona Beach - Melbourne       Clicks     62.00
# 72811                         Philadelphia   Media Cost     18.31
# 22368                               Austin  Impressions  27745.00
# ...

# %%
s['Value'].value_counts()
# Out:
# Value
# 0.00        17376
# 1.00         3489
# 2.00         2479
# 3.00         1742
# 4.00         1414
#             ...
# 37290.00        1
# 11308.00        1
# 52.79           1
# 10822.00        1
# 297.78          1
# Name: count, Length: 43408, dtype: int64

# %%
s['Value'].unique
# Out:
# <bound method Series.unique of 0             1.00
# 1             0.00
# 2             0.00
# 3             1.00
# 4             0.00
#             ...
# 123694      136.94
# 123695       81.00
# 123696    16579.00
# 123697      297.78
# 123698      128.00
# Name: Value, Length: 123699, dtype: float64>

# %%
s['Value'].duplicated().sum()
# Out:
# 80291

# %%
df.tail(5)

# %%
df.sample(10)

# %%
df.loc[0:,['Loan_ID','Education','Credit_History','Property_Area']]

# %%
df.info('Gender')

# %%
df.iloc[:-1,5:-1]

# %%
df.columns

# %%
for i in df.columns:
    if df[i].info() == 'object':
        print("iiii")
    else:
        print("ntg")
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 123699 entries, 0 to 123698
# Series name: Date
# Non-Null Count   Dtype
# --------------   -----
# 123699 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 966.5 KB
# ntg
# <class 'pandas.core.series.Series'>
# RangeIndex: 123699 entries, 0 to 123698
# Series name: Data source
# Non-Null Count   Dtype
# --------------   -----
# 123699 non-null  object
# dtypes: object(1)
# memory usage: 966.5+ KB
# ntg
# <class 'pandas.core.series.Series'>
# RangeIndex: 123699 entries, 0 to 123698
# Series name: Campaign
# Non-Null Count   Dtype
# --------------   -----
# 123699 non-null  object
# dtypes: object(1)
# memory usage: 966.5+ KB
# ntg
# <class 'pandas.core.series.Series'>
# RangeIndex: 123699 entries, 0 to 123698
# Series name: Media Type
# Non-Null Count   Dtype
# --------------   -----
# 123699 non-null  object
# dtypes: object(1)
# memory usage: 966.5+ KB
# ntg
# <class 'pandas.core.series.Series'>
# ...

# %%
dd=df['Credit_History'].count()

# %%
print(type(dd))

# %%
rr=df[i].info() == 'object'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 rr=df[i].info() == 'object'
#
# NameError: name 'i' is not defined

# %%
rr=df[df['Gender']=='Male']

# %%
rr
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1    LP001003   Male     Yes          1      Graduate            No
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# 5    LP001011   Male     Yes          2      Graduate           Yes
# ..        ...    ...     ...        ...           ...           ...
# 607  LP002964   Male     Yes          2  Not Graduate            No
# 608  LP002974   Male     Yes          0      Graduate            No
# 610  LP002979   Male     Yes         3+      Graduate            No
# 611  LP002983   Male     Yes          1      Graduate            No
# 612  LP002984   Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# ...

# %%
rr1=df[df['Education']=='Graduate']

# %%
rr1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 rr1
#
# NameError: name 'rr1' is not defined

# %%
rr2=df.groupby('Education')['ApplicantIncome'].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 rr2=df.groupby('Education')['ApplicantIncome'].sum()
#
# NameError: name 'df' is not defined

# %%
rr2
# Out:
# Education
# Graduate        2197661
# Not Graduate     377170
# Name: ApplicantIncome, dtype: int64

# %%
df['gender'].unique()

# %%
df['gender'].nunique()

# %%
df_new=df[df['gender']=='male']

# %%
#grorp by 
df.groupby(["gender", 'education'])['application'].sum()

# %%
(df.groupby(["gender", 'education'])['application'].sum()).sort_values()

# %%
(df.groupby(["gender", 'education'])['application'].sum()).sort_values(ascending=False)##values in decending order

# %%
(df.groupby(["gender", 'education'])['application'].sum()).sort_values(ascending=False)[:2]#values in decending order with slicing opertor

# %%
(df.groupby(["gender", 'education'])[['application','loanamount']].sum())#double colums count

# %%
(df.groupby(["gender", 'education'])[['application','loanamount']].sum())sort_values(by = 'loanamount',ascending=False)#to print double colums as one columns to ascending or decending order

# %%
pp=[12,1,2,3,4]
for i in pp:
    print(i)
    print("------------------------------11111111111111111111111111-------------------------------")
    uu=mm[(mm['Month']== i) & (mm['Metric']=='Impressions')]
    print(uu)
    print("------------------------------22222222222222222222222222-------------------------------")
    print(mm[mm['Month']== i])
    print("------------------------------33333333333333333333333333-------------------------------")
