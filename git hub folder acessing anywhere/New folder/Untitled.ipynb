# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\ykmi1\Downloads\Campaign data.xlsx",sheet_name=0)

# %%
df1=pd.read_excel(r"C:\Users\ykmi1\Downloads\Campaign data.xlsx",sheet_name=1)

# %%
df
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value
# 0               Colorado Springs-Pueblo  Impressions      1.00
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Data source', 'Campaign', 'Media Type', 'City', 'Metric',
#        'Value'],
#       dtype='object')

# %%
df1
# Out:
#                  Campaign   Message type        Model
# 0       Sentra campaign 2  Future Market       Sentra
# 1       Sentra campaign 4  Future Market       Sentra
# 2       Sentra campaign 3  Future Market       Sentra
# 3       Sentra campaign 1  Future Market       Sentra
# 4       Altima campaign 1  Future Market       Altima
# 5       Altima campaign 5  Future Market       Altima
# 6       Altima campaign 4  Future Market       Altima
# 7       Altima campaign 6  Future Market       Altima
# 8        Kicks campaign 6  Future Market        Kicks
# 9        Kicks campaign 5  Future Market        Kicks
# 10       Rogue campaign 1  Future Market        Rogue
# 11       Rogue campaign 3  Future Market        Rogue
# 12       Rogue pre launch  Future Market        Rogue
# 13       Rogue campaign 5  Future Market        Rogue
# 14       Rogue campaign 4  Future Market        Rogue
# 15  Pathfinder campaign 3    Near Market   Pathfinder
# ...

# %%
ee=pd.merge(df,df1,how='outer')

# %%
ee
# Out:
#              Date Data source           Campaign    Media Type  \
# 0      2020-10-01    Snapchat  Altima campaign 1  Online Video
# 1      2020-10-01    Snapchat  Altima campaign 1  Online Video
# 2      2020-10-01    Snapchat  Altima campaign 1  Online Video
# 3      2020-10-01    Snapchat  Altima campaign 1  Online Video
# 4      2020-10-01    Snapchat  Altima campaign 1  Online Video
# ...           ...         ...                ...           ...
# 123694 2021-09-27   Pinterest       shop at home       Display
# 123695 2021-09-27   Pinterest       shop at home       Display
# 123696 2021-09-27   Pinterest       shop at home       Display
# 123697 2021-09-27   Pinterest       shop at home       Display
# 123698 2021-09-27   Pinterest       shop at home       Display
#
#                               City       Metric    Value   Message type  \
# 0                           Austin  Impressions  5947.00  Future Market
# ...

# %%
ee.columns
# Out:
# Index(['Date', 'Data source', 'Campaign', 'Media Type', 'City', 'Metric',
#        'Value', 'Message type', 'Model'],
#       dtype='object')

# %%
ee['Message type'].unique()
# Out:
# array(['Future Market', 'Near Market'], dtype=object)

# %%
ee.isnull().sum()
# Out:
# Date            0
# Data source     0
# Campaign        0
# Media Type      0
# City            0
# Metric          0
# Value           0
# Message type    0
# Model           0
# dtype: int64

# %%
ee[ee.duplicated()]
# Out:
#              Date Data source      Campaign Media Type  \
# 120536 2021-03-29   Pinterest  shop at home    Display
# 120587 2021-03-29   Pinterest  shop at home    Display
# 120636 2021-03-29   Pinterest  shop at home    Display
# 120637 2021-03-29   Pinterest  shop at home    Display
# 120638 2021-03-29   Pinterest  shop at home    Display
# ...           ...         ...           ...        ...
# 123694 2021-09-27   Pinterest  shop at home    Display
# 123695 2021-09-27   Pinterest  shop at home    Display
# 123696 2021-09-27   Pinterest  shop at home    Display
# 123697 2021-09-27   Pinterest  shop at home    Display
# 123698 2021-09-27   Pinterest  shop at home    Display
#
#                               City       Metric   Value   Message type  \
# 120536                       Utica       Clicks    3.00  Future Market
# 120587                       Utica       Clicks    3.00  Future Market
# 120636                       Utica  Impressions  750.00  Future Market
# ...

# %%
df.describe(include='all')
# Out:
#                                  Date Data source           Campaign  \
# count                          123699      123699             123699
# unique                            NaN           2                 58
# top                               NaN   Pinterest  Armada campaign 2
# freq                              NaN       66945              13392
# mean    2021-02-09 21:36:27.868940032         NaN                NaN
# min               2019-12-30 00:00:00         NaN                NaN
# 25%               2020-10-21 00:00:00         NaN                NaN
# 50%               2021-02-01 00:00:00         NaN                NaN
# 75%               2021-08-04 00:00:00         NaN                NaN
# max               2021-09-30 00:00:00         NaN                NaN
# std                               NaN         NaN                NaN
#
#           Media Type      City       Metric         Value
# count         123699    123699       123699  1.236990e+05
# ...

# %%
df['Data source'].unique()
# Out:
# array(['Pinterest', 'Snapchat'], dtype=object)

# %%
df['Data source'].nunique()
# Out:
# 2

# %%
df['Campaign'].unique()
# Out:
# array(['Kicks campaign 2', 'Kicks campaign 1', 'Armada campaign 2',
#        'Sentra campaign 2', 'Sentra campaign 4', 'Sentra campaign 3',
#        'Sentra campaign 1', 'Sentra campaign 11', 'Sentra campaign 14',
#        'Sentra campaign 20', 'Sentra campaign 21', 'Sentra campaign 9',
#        'Sentra campaign 7', 'Sentra campaign 6', 'Sentra campaign 12',
#        'Sentra campaign 19', 'Sentra campaign 18', 'Sentra campaign 5',
#        'Sentra campaign 13', 'Sentra campaign 15', 'Sentra campaign 8',
#        'Sentra campaign 10', 'Sentra campaign 16', 'Sentra campaign 17',
#        'Sentra campaign 22', 'Sentra campaign 23', 'Sentra campaign 25',
#        'Sentra campaign 24', 'Altima campaign 3', 'Altima campaign 2',
#        'Altima campaign 1', 'Altima campaign 5', 'Altima campaign 6',
#        'Altima campaign 7', 'Altima campaign 8', 'Rogue pre launch',
#        'Altima campaign 4', 'Rogue campaign 5', 'Rogue campaign 4',
# ...

# %%
df['Campaign'].nunique()
# Out:
# 58

# %%
df['Media Type'].unique()
# Out:
# array(['Display', 'Online Video'], dtype=object)

# %%
df['Media Type'].nunique()
# Out:
# 2

# %%
df['Metric'].unique()
# Out:
# array(['Impressions', 'Media Cost', 'Clicks'], dtype=object)

# %%
df['Metric'].value_counts()
# Out:
# Metric
# Impressions    41233
# Media Cost     41233
# Clicks         41233
# Name: count, dtype: int64

# %%
df['Metric'].nunique()
# Out:
# 3

# %%
ee['Model'].unique()
# Out:
# array(['Altima', 'Armada', 'Kicks', 'Pathfinder', 'Rogue', 'Sentra',
#        'Multi-Model'], dtype=object)

# %%
ee['Model'].nunique()
# Out:
# 7

# %%
ee.sample(20)
# Out:
#              Date Data source               Campaign    Media Type  \
# 52688  2021-05-24   Pinterest       Kicks campaign 4  Online Video
# 90941  2021-01-04   Pinterest       Rogue campaign 2  Online Video
# 16180  2020-10-22    Snapchat      Altima campaign 6  Online Video
# 65508  2021-09-27   Pinterest  Pathfinder campaign 2  Online Video
# 120708 2021-03-29   Pinterest           shop at home       Display
# 123642 2021-09-27   Pinterest           shop at home  Online Video
# 96360  2020-11-14    Snapchat       Rogue campaign 4  Online Video
# 101440 2021-01-26    Snapchat       Rogue campaign 4  Online Video
# 48344  2021-03-22   Pinterest       Kicks campaign 3  Online Video
# 21538  2021-08-16   Pinterest      Altima campaign 8       Display
# 20650  2020-11-23   Pinterest      Altima campaign 8  Online Video
# 83368  2021-08-15    Snapchat  Pathfinder campaign 8  Online Video
# 16635  2020-10-12   Pinterest      Altima campaign 7  Online Video
# ...

# %%
len(ee)
# Out:
# 123699

# %%
mm=ee.sort_values('Date', ascending=True)

# %%
mm.head(20)
# Out:
#             Date Data source          Campaign    Media Type  \
# 43644 2019-12-30   Pinterest  Kicks campaign 1  Online Video
# 44477 2019-12-30   Pinterest  Kicks campaign 2       Display
# 44476 2019-12-30   Pinterest  Kicks campaign 2       Display
# 44475 2019-12-30   Pinterest  Kicks campaign 2       Display
# 44474 2019-12-30   Pinterest  Kicks campaign 2       Display
# 44473 2019-12-30   Pinterest  Kicks campaign 2       Display
# 44472 2019-12-30   Pinterest  Kicks campaign 2       Display
# 43658 2019-12-30   Pinterest  Kicks campaign 1  Online Video
# 43657 2019-12-30   Pinterest  Kicks campaign 1  Online Video
# 43656 2019-12-30   Pinterest  Kicks campaign 1  Online Video
# 43645 2019-12-30   Pinterest  Kicks campaign 1  Online Video
# 43654 2019-12-30   Pinterest  Kicks campaign 1  Online Video
# 43649 2019-12-30   Pinterest  Kicks campaign 1  Online Video
# 43648 2019-12-30   Pinterest  Kicks campaign 1  Online Video
# ...

# %%
mm.tail(10)
# Out:
#             Date Data source               Campaign    Media Type  \
# 82230 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 82229 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 82228 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 82227 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 73641 2021-09-30    Snapchat  Pathfinder campaign 5  Online Video
# 73642 2021-09-30    Snapchat  Pathfinder campaign 5  Online Video
# 73643 2021-09-30    Snapchat  Pathfinder campaign 5  Online Video
# 73644 2021-09-30    Snapchat  Pathfinder campaign 5  Online Video
# 82234 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 67571 2021-09-30    Snapchat  Pathfinder campaign 3  Online Video
#
#                              City       Metric    Value Message type  \
# 82230                  Washington  Impressions  9138.00  Near Market
# 82229  Cleveland - Akron (canton)       Clicks    51.00  Near Market
# ...

# %%
ee.groupby(["Date"])[['Metric']].sum()
# Out:
#                                                        Metric
# Date
# 2019-12-30  ImpressionsMedia CostClicksImpressionsMedia Co...
# 2020-01-06  ImpressionsMedia CostClicksImpressionsMedia Co...
# 2020-01-13  ImpressionsMedia CostClicksImpressionsMedia Co...
# 2020-01-20  ImpressionsMedia CostClicksImpressionsMedia Co...
# 2020-01-27  ImpressionsMedia CostClicksImpressionsMedia Co...
# ...                                                       ...
# 2021-09-26  ImpressionsMedia CostClicksImpressionsMedia Co...
# 2021-09-27  ImpressionsMedia CostClicksImpressionsMedia Co...
# 2021-09-28  ImpressionsMedia CostClicksImpressionsMedia Co...
# 2021-09-29  ImpressionsMedia CostClicksImpressionsMedia Co...
# 2021-09-30  ImpressionsMedia CostClicksImpressionsMedia Co...
#
# [332 rows x 1 columns]

# %%
ertyuio9090=mm[mm['Metric']=='Impressions']

# %%
ertyuio9090['Metric'].s
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16724\3821314007.py in ?()
# ----> 1 ertyuio9090['Metric'].s
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 's'

# %%
mm['Date']=pd.to_datetime(mm['Date'])

# %%
mm

# %%
mm['Day']=mm['Date'].dt.day

# %%
mm['Month']=mm['Date'].dt.month

# %%
mm['Year']=mm['Date'].dt.year

# %%
mm.drop("Date",axis=1)

# %%
mm

# %%
q1=mm[mm['Metric']=='Impressions']

# %%
q1

# %%
pp=mm['Month'].unique

# %%
q2=q1.groupby(['Year','Month'])['Value'].sum()
arr=q2.sort_values(ascending = False).head(5)
arr

# %%
q2=q1.groupby(['Metric'])['Model'].sum()

# %%
nu=ee['Campaign'],['Model']
nu

# %%
pd.DataFrame(nu)

# %%
q2=.groupby(['Metric'])['Model'].value_counts()

# %%
q3

# %%
q2=q1.groupby(['Metric'])['Model'].value_counts()
m=pd.DataFrame(q2)
print(m)

# %%
m=q1['Model'].value_counts().head(1)

# %%
m

# %%
yyy=pd.DataFrame(m)

# %%
yyy

# %%
yyy['count'].head(5)#['Model']

# %%
print(max(yyy['count']))

# %%
ee['Message type'].unique()

# %%
q3=ee.groupby(['Message type'])['Campaign'].value_counts()

# %%
q3

# %%
ww33=pd.DataFrame(q3)

# %%
ww33

# %%
ww33['count']

# %%
q333=ee.groupby(['Message type'])['Campaign'].value_counts().sort_values(ascending=True)

# %%
q333.sort_values(ascending=False)

# %%
eee=ee[(ee['Metric']=='Clicks') &(ee['Campaign']=='Altima campaign 1')]

# %%
eee

# %%
rrrttt=ee.groupby(['Campaign'])['Metric'].value_counts().sort_values(ascending=False).head(1)

# %%
pd.DataFrame(rrrttt)

# %%
for i in rrrttt:
    print(i)

# %%
w324e=ee['Campaign'].unique()

# %%
w324e

# %%
for i in w324e:
    eeee=ee[ee[i]== 'Sentra campaign 18']
    print(eeee)

# %%
ee

# %%
eee=ee[ee['Metric']=='Clicks']

# %%
eee

# %%
dfg=eee['Metric'].value_counts()

# %%
dfg

# %%
rrew=(eee.groupby(['Campaign'])[['Metric']].value_counts().sort_values(ascending=False).head(1)).reset_index()
#to change value in data framev

# %%
rrew

# %%
dataset['cpm']=(datasetcolumn name['']/datasetcolumn name[''])*1000
# Out:
#   Cell In[33], line 1
#     dataset['cpm']=(datasetcolumn name['']/datasetcolumn name[''])*1000
#                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
aaaaaaaa=ee['Campaign']

# %%
pd.DataFrame(aaaaaaaa)

# %%
aaaaaaaa['Campaign']

# %%
for i in aaaaaaaa :
    print(ee[i].value_counts())
    #print(b)

# %%
wew23=ee.columns

# %%
wew23

# %%
for i in wew23:
    print(i)
    try:
        dd=ee[i].sum() 
    except:
        dd1=ee[i].value_counts()
    else:
        print(dd)
    print(f"-------------------------------------------- { i } ----------------------------------------------------")
    #dd=ee[i].value_counts()
    print(dd1)
    print("------------------------------------------------------------------------------------------------")

# %%
we345=ee[['Campaign']].value_counts().head(3)

# %%
we345

# %%
de3456=pd.DataFrame(we345)

# %%
de3456['count']

# %%
we345.rename(columns={'count': 'counts'})

# %%
we345['count']

# %%
for i in we345['count']:
    print(i)
